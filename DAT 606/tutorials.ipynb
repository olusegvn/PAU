# %%
import numpy as np

a= np.array([[1, 2, 3]])
b = np.array([[4],
                [5],
                [6]])

4, 8, 12
5, 10, 15
6, 12, 18

[[4, 8, 12],
[5, 10, 15],
[6, 12, 18]]



[[4] [[1, 2, 3]]
[5]
[6]]

dot <- matrix multiply
3x1  dot 1x3
3x3

[[1, 2, 3]]  [[4],
                [5],
                [6]]

1x3 dot 3x1
1x1

np.dot(a, b)
[[32]]
# Out:
# array([[32]])

# %%
4+10+18
# Out:
# 32

# %%
b

# %%
single_data_point = np.array([[24.0, 3, 187, 93, 1013ll.0]])


single_data_point = np.array([[24.0, 3, 187, 93, 1013.0],
                             [24.0, 3, 187, 93, 1013.0]
                             [24.0, 3, 187, 93, 1013.0]
                             [24.0, 3, 187, 93, 1013.0]])
